# %% [markdown]
# https://www.youtube.com/watch?v=rdR2fNDq6v0&t=531s

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# from pandas.plotting import register_matplotlib_converters
# register_matplotlib_converters()

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from pmdarima.arima import auto_arima
from statsmodels.tsa.seasonal import seasonal_decompose 
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import itertools

# %%
# Path 설정
import os
import sys
from pathlib import Path
sys.path.append(str(Path(os.getcwd()).parent))

# %% [markdown]
# # 분석 순서

# %%
img = plt.imread('이미지 파일/ARIMA Procedure.png')
plt.figure(figsize = (18,8))
plt.imshow(img)

# %% [markdown]
# 1. 데이터 전처리 (데이터가 nonstationary일 때, transformation이나 differencing을 이용해서 stationary하게 만듦)
# 2. 시범적으로 해볼 모델을 선정 -> 주관적으로 선정하게 되므로 시범적이다.
# 3. 파라미터 추정
# 4. 모델이 괜찮은지 체크 => 괜찮지 않다면 2번 스텝으로(만든 모델의 잔차의 ACF PLOT을 통해 확인하는데 40개중 2~3개정도의 튀는정도는 허용이된다.)
# 5. 예측하기

# %% [markdown]
# # Data Preprocessing

# %%
df=pd.read_csv('https://raw.githubusercontent.com/sm-joo/sm-joo/master/DEXKOUS.csv', parse_dates=['DATE'], index_col='DATE')

# %%
df.columns =['KOUS']
df['KOUS'].replace('.', '', inplace =True)
df['KOUS'] = pd.to_numeric(df['KOUS'])
df['KOUS'].fillna(method = 'ffill', inplace = True)

# %%
df.plot(figsize = (12, 5))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1306 entries, 2015-03-13 to 2020-03-13
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   KOUS    1306 non-null   float64
# dtypes: float64(1)
# memory usage: 20.4 KB

# %%
df = df[(df.index>'2016-01-01') & (df.index < '2020-01-01')]

# %% [markdown]
# ##  Stationary한 데이터 여부 확인하기

# %%
result = seasonal_decompose(df, model = 'additive', two_sided = False)
fig = result.plot()
fig.set_size_inches(10,10)
plt.show()

# %%
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# 시각화
# subplot생성
fig, ax = plt.subplots(1,2 , figsize = (12,4))

# acf plot
plot_acf(df, ax = ax[0])

# pacf plot
plot_pacf(df, ax= ax[1])
plt.show()
# Out:
# /Users/jeongseok/opt/anaconda3/envs/main/lib/python3.8/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# ACF plot을 보면 시차에따른 상관관계가 있는것을 알 수 있다. 따라서, 정상성을 만족하지 않는 데이터이다.

# %% [markdown]
# ## 데이터셋 분리

# %%
train_df, test_df = train_test_split(df, test_size = 0.2, shuffle = False) # 시계열이기 때문에 shuffle = False

# %% [markdown]
# # 시범모델 찾기

# %% [markdown]
# ## ARIMA(p,d,q) => d 결정

# %%
adfuller(train_df.KOUS)[1]
# Out:
# 0.09142553057470132

# %% [markdown]
# 위에서acf,pacf도표를 통해 non-stationary 하다는것을 확인했고 adfuller를통해 p-value까지 확인 해 보았다.

# %% [markdown]
# p-value가 0.36으로 귀무가설이이 기각되지 않는다 -> 안정적이지 않다 따라서 차분이 필요하다

# %%
adfuller(train_df.KOUS.diff().dropna())
# Out:
# (-16.097698942106142,
#  5.171593388195271e-29,
#  3,
#  828,
#  {'1%': -3.438272329479064,
#   '5%': -2.8650369467745573,
#   '10%': -2.568632068251301},
#  5246.158794778041)

# %% [markdown]
# 차분을 1회 했을때 p-value가 0.05이하로 떨어지며 귀무가설이 기각되는 모습을 보인다.

# %%
diff_train_df = train_df.KOUS.diff().dropna()

# %%
plt.figure(figsize= (12,8))
plt.subplot(311)
plt.plot(train_df)
plt.legend('RawData')
plt.subplot(312)
plt.plot(diff_train_df, 'orange')
plt.legend('DifferencedData')
plt.show()

# %% [markdown]
# 1회 차분했을때 평균과 분산이 훨씬 좋아진모습이다.

# %%
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# 시각화
# subplot생성
fig, ax = plt.subplots(1,2 , figsize = (12,4))

# acf plot
plot_acf(diff_train_df, ax = ax[0])

# pacf plot
plot_pacf(diff_train_df, ax= ax[1])
plt.show()
# Out:
# /Users/jeongseok/opt/anaconda3/envs/main/lib/python3.8/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# acf도표와, pacf도표 또한 훨씬 안정적인 모양이다.

# %%
figure, axes =plt.subplots(2, 3, figsize =(15,7))
axes[0,0].plot(df.KOUS)
axes[0,0].set_title('original set')
axes[1,0].plot(df.KOUS.diff())
axes[1,0].set_title('1st difference series')
plot_acf(df.KOUS, axes[0,1])
plot_pacf(df.KOUS, axes[0,2])
plot_acf(diff_train_df, axes[1,1])
plot_pacf(diff_train_df, axes[1,2])
plt.show()
# Out:
# /Users/jeongseok/opt/anaconda3/envs/main/lib/python3.8/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(
# /Users/jeongseok/opt/anaconda3/envs/main/lib/python3.8/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %% [markdown]
# # 파라미터 추정(ARIMA(p,k,q) => p, q 결정)

# %% [markdown]
# ARIMA 모델의 잘 알려진 일부 예
# - ARIMA(0,0,0)는 백색잡음 모델입니다.
# - ARIMA(0,1,0)은 확률보행모델이며, 0이아닌 상수로 구성된 ARIMA(0,1,0)은 표류가 있는 확률보행입니다.
# - ARIMA(0,1,1,)는 지수평활 모델이고, ARIMA(0,2,2)는 지수평활추세를 가진 데이터로 확장시킨 홀트의 선형 방법과 같다.(추세를 기반으로 한 예측에 사용될 수 있다.)
# - ARIMA(p,0,0) 은 자기회귀 모델, ARIMA(0,0,q)는 이동평균이다.

# %% [markdown]
# < 백색잡음 모델 >
# - 자기상관(autocorrelation)이 없는 시계열을 백색 잡음(white noise)라고 부른다.
# - 자기상관함수(ACF)도표를 통해서 확인해 보면 모두 상관관계가 없는것을 확인해 볼수 있다.
# - 시계열 데이터 통계분석에서 백색잡음과정(white noise process) 는 평균이0, 분산이 유한한 상수(sigma^2)인 확률분포로 부터 서로 상관되지 않게 무작위로 샘플을 추출한 신호를 말한다.
# - 강한 정상성을 가지고 있는데이터 이다.
#
# < 확률보행(Random Walk) >
# - 확률보행과정은 백색잡음과 달리 '비정상성'을 가지고 있는 데이터이다. 따라서 ARIMA모델에 적용시키기 위해서는 정상화 시켜야하는데 확률보행은 상수가 있는것과 없는것으로 나누어져 있다.
# - 확률보행의 경우 임의의 방향으로 향하는 연속적인 걸음을 나타내는 의미로, 예측 불가능한 변동이 발생하는 것을 뜻한다. 예를들어 위로갈 확률이 0.3 아래로갈 확률이 0.7일경우 주식차트처럼 오르락 내리락 할것이다.

# %% [markdown]
# ## Graphical method를 통한 시범적인 파라미터 추정

# %%
img2 = plt.imread('./이미지 파일/Graphical_method.png')
plt.figure(figsize =(18,8))
plt.imshow(img2)

# %% [markdown]
# 위의 과정에서 차분이전에 ACF, PACF 도표를 다시 돌아가보면 AR의 경우1시차 이후 0으로 절단이 되며, ACF의 경우 지수적으로 감소했고(AR모델로는 stationary), 차분후 MA를 살펴보았을때는 지수적으로 감소하고나 특정시차이후 절단이 없었기때문에 AR(1)모델을 베이스 모델로 사용해 보자(차분1회)
#
# 참고로 ARIMA모델을 사용할때 파라미터를 선정하는데 있어서 p*q = 0이고 p+q < 2 인 값을 많이쓴다고 한다.
#
# 그리고 시계열 데이터가 AR특성을 띄는 경우 위처럼 ACF는 서서히 감소하고, PACF는 p시차를 제외하고 급격히 감소하며, MA의 경우 ACF는 q시차 이후 급격히 감소하고 PACF는 천천히 감소한다. 급격히 감소하는 시차를 각각  AR과 MA의 모수(p,q)로 사용가능하다.

# %% [markdown]
# ## ARIMA 임시 모델 적용하기

# %% [markdown]
# 파라미터 설명
# - order : AR차수, 차분횟수, MA차수
# - freq : 날짜
#
#     'B' - business day, ie., Mon. - Fri.
#     'D' - daily
#     'W' - weekly
#     'M' - monthly
#     'A' - annual
#     'Q' - quarterly
# - trend : 상수항 포함여부, 'c'(constant) or 'nc'(no constant) -> 'c'를 했을때 constant가 0.05보다 크게나온다면 nc를 하는게 좋다.

# %%
########
# 여기서 안정성 있으려면 1회차분이 있어야 했었는데, AR(1)모델의 경우 차분하기전에 AR(1)이 적합으로 나왔는데 그렇다면 차분을 넣어야
# 하는가 빼야하는가

# %%
model =ARIMA(train_df, order = (1,1,0), freq = 'B')
model_fit = model.fit()
model_fit.summary()
# Out:
# /Users/jeongseok/opt/anaconda3/envs/main/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                   KOUS   No. Observations:                  833
# Model:                 ARIMA(1, 1, 0)   Log Likelihood               -2699.181
# Date:                Tue, 26 Jul 2022   AIC                           5402.361
# Time:                        23:22:33   BIC                           5411.809
# Sample:                    01-04-2016   HQIC                          5405.984
#                          - 03-13-2019
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## 더 좋은 파라미터 찾기

# %% [markdown]
# ##### 추후에 해결할점 : AIC와 likelihood의 값이 각각 최소, 최고가 되는 파라미터를 정하게되었을 때 p-vlaue가 좋지 않은 경우 이 모델에 대해 어떻게 평가해야하는가..

# %%
p = range(0, 3)
d = range(0, 2)
q = range(0, 3)
pdq = list(itertools.product(p, d, q))

dict_model = {}
for i in pdq:
    
    try:
        model = ARIMA(train_df, order = (i))
        print(i)
        model_fit = model.fit()
        dict_model[i] = [model_fit.llf, model_fit.aic]
    except:
        print('error lag:', i)
# Out:
# /Users/jeongseok/opt/anaconda3/envs/main/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /Users/jeongseok/opt/anaconda3/envs/main/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /Users/jeongseok/opt/anaconda3/envs/main/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# /Users/jeongseok/opt/anaconda3/envs/main/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# ...

# %%
params_df = pd.DataFrame.from_dict(dict_model, orient = 'index',columns = ['llf','aic'])
params_df
# Out:
#                    llf          aic
# (0, 0, 0) -4193.698232  8391.396465
# (0, 0, 1) -3698.217863  7402.435726
# (0, 0, 2) -3395.750300  6799.500601
# (0, 1, 0) -2699.180965  5400.361929
# (0, 1, 1) -2699.180402  5402.360804
# (0, 1, 2) -2694.599345  5395.198690
# (1, 0, 0) -2701.454824  5408.909649
# (1, 0, 1) -2701.474063  5410.948126
# (1, 0, 2) -2697.528798  5405.057596
# (1, 1, 0) -2699.180512  5402.361024
# (1, 1, 1) -2696.803498  5399.606995
# (1, 1, 2) -2694.338584  5396.677167
# (2, 0, 0) -2701.428589  5410.857177
# (2, 0, 1) -2698.938266  5407.876532
# (2, 0, 2) -2697.013860  5406.027719
# (2, 1, 0) -2695.272545  5396.545090
# (2, 1, 1) -2694.553507  5397.107015
# (2, 1, 2) -2692.889968  5395.779937

# %%
params_df[params_df['llf']==params_df['llf'].max()]
# Out:
#                    llf          aic
# (2, 1, 2) -2692.889968  5395.779937

# %%
params_df[params_df['aic']==params_df['aic'].min()]
# Out:
#                    llf         aic
# (0, 1, 2) -2694.599345  5395.19869

# %% [markdown]
# likelihood 로 보았을때는 ARIMA(2,0,2)모델이 , AIC 로 보았을땐 ARIMA(2, 0, 0) 가장좋은 모델이다. LLR TEST를 통해서 Likelihood가 유의미 하게 다른지 검증해보고 모델을 선택해보자.

# %%
from scipy.stats.distributions import chi2
L1 = 1261.013945
L2 = 1259.366313
LR = (2*(L2-L1))
p = chi2.sf(LR, 2)
p
# Out:
# 1.0

# %% [markdown]
# LLR테스트 결과 두개의 Likelihood는 다를 확률이 높기때문에 각각 적용해서 p-value도 확인해보자

# %%
tmp_model1 =ARIMA(train_df, order =(2,1,2), freq = 'B')
model_fit1 = tmp_model1.fit()
model_fit1.summary()
# Out:
# /Users/jeongseok/opt/anaconda3/envs/main/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                   KOUS   No. Observations:                  833
# Model:                 ARIMA(2, 1, 2)   Log Likelihood               -2692.890
# Date:                Tue, 26 Jul 2022   AIC                           5395.780
# Time:                        23:22:47   BIC                           5419.399
# Sample:                    01-04-2016   HQIC                          5404.837
#                          - 03-13-2019
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
tmp_model2 =ARIMA(train_df, order =(0,1,2), freq = 'B')
model_fit2 = tmp_model2.fit()
model_fit2.summary()
# Out:
# /Users/jeongseok/opt/anaconda3/envs/main/lib/python3.8/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                   KOUS   No. Observations:                  833
# Model:                 ARIMA(0, 1, 2)   Log Likelihood               -2694.599
# Date:                Tue, 26 Jul 2022   AIC                           5395.199
# Time:                        23:22:51   BIC                           5409.370
# Sample:                    01-04-2016   HQIC                          5400.633
#                          - 03-13-2019
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# 파라미터의 p-value는 ARIMA(0,1,2)모델이 조금 더 좋게 나온다는것을 알 수 있다. 이때는 aic를 선택하는게 맞을까??
#
# 만약에 aic와 likelihood 관점에서 각각의 최적의 파라미터값결과를 보고 LLR test가 유의하게 나왔다면 그때는 p-value가 높아도 해당모델을 써도 되는가?? --> 예측을 하는거라면 p값이 높아도 그냥 써도되지않을까?

# %% [markdown]
# # 모델 적합도 체크(Diagnosis check)

# %% [markdown]
# ## 잔차들의 ACF도표를 통한 확인

# %%
# model1 
plot_acf(model_fit1.resid)
plt.show()

# %%
# model2
plot_acf(model_fit2.resid)
plt.show()

# %%
# https://assaeunji.github.io/data%20analysis/2021-09-25-arimastock/
model_fit2.plot_diagnostics(figsize = (15, 5))
plt.show()

# %% [markdown]
# ## Argumentd dickey fuller test

# %%
adfuller(model_fit1.resid)
# Out:
# (-195.4829171381506,
#  0.0,
#  0,
#  832,
#  {'1%': -3.4382341228740345,
#   '5%': -2.865020104308721,
#   '10%': -2.568623096396542},
#  5246.054679923714)

# %%
adfuller(model_fit2.resid)
# Out:
# (-195.0752682942878,
#  0.0,
#  0,
#  832,
#  {'1%': -3.4382341228740345,
#   '5%': -2.865020104308721,
#   '10%': -2.568623096396542},
#  5249.558790842936)

# %% [markdown]
# p-value가 0.05보다 작은것으로 보아 귀무가설인 non-staionary한 시계열인것을 기각하고 정상 시계열임을 채택할 수 있다.

# %%
# def my_auto_arima(data, order, sort='AIC'):
#     order_list = []
#     aic_list = []
#     bic_lsit = []

#     for p in range(order[0]):
#         for d in range(order[2]):
#             for q in range(order[2]):
#                 model = ARIMA(data, order=(p, d, q), freq = 'B')

#                 try:
#                     model_fit = model.fit(trend='nc')
#                     c_order = f'p{p} d{d} q{q}'
#                     aic = model_fit.aic
#                     bic = model_fit.bic
#                     order_list.append(c_order)
#                     aic_list.append(aic)
#                     bic_list.append(bic)
#                 except:
#                     pass

#                 result_df = pd.DataFrame(list(zip(order_list, aic_list)),
#                                          columns=['order', 'AIC'])
#                 result_df.sort_values(sort, inplace=True)

#     return result_df
# my_auto_arima(df['KOUS'], [3,1,3])

# %% [markdown]
# # 예측해보기

# %% [markdown]
# arima계열 데이터는 데이터가 너무많으면 예측하기에 별로안좋다??

# %%
model = ARIMA(train_df, order = (2,1,2), freq = 'B')
model_fit = model.fit()
result = model_fit.get_forecast(steps = len(test_df.index), alpha = 0.05).summary_frame()

fc = tuple(result['mean'].values) # 예측값
se = tuple(result['mean_se'].values) # 표준오차
lower_coef = tuple(result['mean_ci_lower'].values) # 신뢰구간 최소
upper_coef = tuple(result['mean_ci_upper'].values) # 신뢰구간 최대

# 예측값 인덱스 넣기
fc_data = pd.Series(fc, index = test_df.index)

# 신뢰구간 인덱스 넣기
lower_data = pd.Series(lower_coef, index = test_df.index)
upper_data = pd.Series(upper_coef, index = test_df.index )

# VIZ
plt.figure(figsize =(15, 6))
plt.plot(train_df, label = 'training')
plt.plot(test_df, label = 'actual')
plt.plot(fc_data, label = 'forecast')
plt.fill_between(test_df.index, lower_data, upper_data, color = 'black', alpha = 0.1)
plt.legend(loc = 'upper left')
plt.show()
# Out:
# C:\Users\jeongseokLim\anaconda3\envs\aide\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)

# %%
model = ARIMA(train_df, order = (0,1,2), freq = 'B')
model_fit = model.fit()
result = model_fit.get_forecast(steps = len(test_df.index), alpha = 0.05).summary_frame()

fc = tuple(result['mean'].values) # 예측값
se = tuple(result['mean_se'].values) # 표준오차
lower_coef = tuple(result['mean_ci_lower'].values) # 신뢰구간 최소
upper_coef = tuple(result['mean_ci_upper'].values) # 신뢰구간 최대

# 예측값 인덱스 넣기
fc_data = pd.Series(fc, index = test_df.index)

# 신뢰구간 인덱스 넣기
lower_data = pd.Series(lower_coef, index = test_df.index)
upper_data = pd.Series(upper_coef, index = test_df.index )

# VIZ
plt.figure(figsize =(15, 6))
plt.plot(train_df, label = 'training')
plt.plot(test_df, label = 'actual')
plt.plot(fc_data, label = 'forecast')
plt.fill_between(test_df.index, lower_data, upper_data, color = 'black', alpha = 0.1)
plt.legend(loc = 'upper left')
plt.show()
# Out:
# C:\Users\jeongseokLim\anaconda3\envs\aide\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)

# %% [markdown]
# # 그외 모델 알아보기

# %% [markdown]
# ARIMAX : 일종의 회귀모형으로 볼 수 있다. 일번적인 AR이나 MA모형의 경우 단변량 시계열을 표현하는데 적절하다. 하지만, ARIMAX모형은 추가적인 외생 변수(Explanatory variable)을 활용함으로서 다변량 시계열 데이터를 활용하기에 적절한 모형디ㅏ.
#
# SARIMA : 말그대로 계절성(Seasonal)을 포함하는 모델이다. SARIMA(p,d,q)(P,D,Q,S)로  표현한다.
#     - p : order of non-seasonal AR terms
#     - d : order of non-seasonal differencing
#     - q : order of non-seasonal MA terms
#     - P : order of seasonal AR terms
#     - D : order of seasonal differencing
#     - Q : order of seasonal MA terms
#     - S : length of the cycle
#
# SARIMAX : ARIMAX와 마찬가지로 기존 SARIMA 모형에, 외생변수 X를 포함하여 모형을 수립한다.
#     - SARIMA나 SARIMAX의 경우에는 객관적으로 차수를 정하는 것이 어려운 것 같다. 따라서 실무에서 많은 경우 grid search를
#     활용하여  AIC, BIC, 예측력을 기준으로 차수를 정하는 경우도 많다.

# %% [markdown]
# ## SARIMA 모델

# %% [markdown]
# ARIMA 모형은 주기성 및 계절성이 강하거나 불규칙한 데이터에 한계를 보이고 있어 교통량 데이터와 같
# 은 자료에 적용하기에는 한계가 있다. 이러한 한계점을 극복하고 보완하기 위해 ARIMA 모형에 자기상관 모
# 형인 SAR(Seasonal Auto Regressive)과 계절 이동평균 모형인 SMA(Seasonal Moving Average)가 결합된 분석
# 기법이 SARIMA 모형이다.
#
# ARIMA가 추세를 통해서 예측을 하는 모델이며 정상성을 만족해야하기 때문에 non-seasonality 하지만, SARIMA는 Seasonal이 추가가된다 즉, 추세성 + 계절성으로 예측을 하는 모델이다.

# %%
# Parameter grid search
p = range(0, 3)
d = range(0, 2)
q = range(0, 3)
pdq  = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2],12) for x in list(itertools.product(p, d, q))]

dict_model = {}

for i in pdq:
    for j in seasonal_pdq:
        try:
            model = SARIMAX(train_df, order = (i), seasonal_order = (j))
            print(i, j)
            model_fit = model.fit()
            dict_model[i,j] = [model_fit.llf, model_fit.aic]
        
        except:
            continue
# Out:
# C:\Users\jeongseokLim\anaconda3\envs\jupyter\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# C:\Users\jeongseokLim\anaconda3\envs\jupyter\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# C:\Users\jeongseokLim\anaconda3\envs\jupyter\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# C:\Users\jeongseokLim\anaconda3\envs\jupyter\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# (0, 0, 0) (0, 0, 0, 12)
# (0, 0, 0) (0, 0, 1, 12)
# ...

# %%
params_df = pd.DataFrame.from_dict(dict_model, orient = 'index',columns = ['llf','aic'])
params_df
# Out:
#                                     llf           aic
# ((0, 0, 0), (0, 0, 0, 12)) -7037.707070  14077.414140
# ((0, 0, 0), (0, 0, 1, 12)) -6492.672842  12989.345684
# ((0, 0, 0), (0, 0, 2, 12)) -6074.588126  12155.176251
# ((0, 0, 0), (0, 1, 0, 12)) -3569.139649   7140.279298
# ((0, 0, 0), (0, 1, 1, 12)) -3564.668422   7133.336844
# ...                                 ...           ...
# ((2, 1, 2), (2, 0, 1, 12)) -2690.864809   5397.729619
# ((2, 1, 2), (2, 0, 2, 12)) -2690.839220   5399.678439
# ((2, 1, 2), (2, 1, 0, 12)) -2772.522103   5559.044205
# ((2, 1, 2), (2, 1, 1, 12)) -2678.265871   5372.531742
# ((2, 1, 2), (2, 1, 2, 12)) -2678.022493   5374.044985
#
# [324 rows x 2 columns]

# %%
params_df[params_df['llf']==params_df['llf'].max()]
# Out:
#                                     llf          aic
# ((2, 1, 2), (2, 1, 2, 12)) -2678.022493  5374.044985

# %%
params_df[params_df['aic']==params_df['aic'].min()]
# Out:
#                                     llf          aic
# ((0, 1, 2), (0, 1, 1, 12)) -2681.274578  5370.549157

# %%
from scipy.stats.distributions import chi2
L1 = -2678.022493
L2 = -2681.274578
LR = (2*(L2-L1))
p = chi2.sf(LR, 2)
p
# Out:
# 1.0

# %% [markdown]
# 또한 그냥 ARIMA모델을 사용했을때보다 조금 더 좋은 수치를 보여주는것을 알 수 있다.

# %%
model_sarima = SARIMAX(train_df, order = (0,1,2), seasonal_order = (0,1,1,12))
model_sarima_fit = model_sarima.fit()
model_sarima_fit.summary()
# Out:
# C:\Users\jeongseokLim\anaconda3\envs\jupyter\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# C:\Users\jeongseokLim\anaconda3\envs\jupyter\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ...
# Dep. Variable:                                 KOUS   No. Observations:                  833
# Model:             SARIMAX(0, 1, 2)x(0, 1, [1], 12)   Log Likelihood               -2681.275
# Date:                              Mon, 25 Jul 2022   AIC                           5370.549
# Time:                                      21:26:03   BIC                           5389.386
# ...

# %%
model_sarima2 = SARIMAX(train_df, order = (2,1,2), seasonal_order = (2,1,2,12))
model_sarima_fit2 = model_sarima2.fit()
model_sarima_fit2.summary()
# Out:
# C:\Users\jeongseokLim\anaconda3\envs\jupyter\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# C:\Users\jeongseokLim\anaconda3\envs\jupyter\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency B will be used.
#   self._init_dates(dates, freq)
# C:\Users\jeongseokLim\anaconda3\envs\jupyter\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\jeongseokLim\anaconda3\envs\jupyter\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# ...

# %% [markdown]
# 두개의 모델 모두 돌려봤을땐 후자가 p_value수치는 좋게나온다.

# %%
# 모델 검증( 잔차의 ACF, 잔차의 adful`ler)
plot_acf(model_sarima_fit.resid)
plt.show()

# %%
plot_acf(model_sarima_fit2.resid)
plt.show()

# %%
adfuller(model_sarima_fit.resid)
# Out:
# (-62.43481270224801,
#  0.0,
#  0,
#  832,
#  {'1%': -3.4382341228740345,
#   '5%': -2.865020104308721,
#   '10%': -2.568623096396542},
#  5326.976061420091)

# %%
adfuller(model_sarima_fit2.resid)
# Out:
# (-62.451514402167774,
#  0.0,
#  0,
#  832,
#  {'1%': -3.4382341228740345,
#   '5%': -2.865020104308721,
#   '10%': -2.568623096396542},
#  5320.472825501343)

# %%
prediction = model_sarima_fit.get_forecast(len(test_df)).summary_frame()
predicted_value = prediction['mean']
predicted_lower = prediction['mean_ci_lower']
predicted_upper = prediction['mean_ci_upper']
predict_index = list(test_df.index)
r2 = r2_score(test_df, predicted_value)

# %%
r2
# Out:
# -5.872332181808967

# %%
fig, ax = plt.subplots(figsize = (12, 6))
ax.plot(train_df, label = 'train_data')
ax.plot(test_df, label = 'test_data')
ax.plot(predict_index, predicted_value, label = 'Prediction')
ax.fill_between(predict_index, predicted_upper, predicted_lower, color = 'k', alpha = 0.1, label = '0.95 Prediction Interval')
ax.legend(loc = 'upper left')
plt.show()

# %%
prediction = model_sarima_fit2.get_forecast(len(test_df)).summary_frame()
predicted_value = prediction['mean']
predicted_lower = prediction['mean_ci_lower']
predicted_upper = prediction['mean_ci_upper']
predict_index = list(test_df.index)
r2 = r2_score(test_df, predicted_value)

# %%
r2
# Out:
# -6.092914686130553

# %%
fig, ax = plt.subplots(figsize = (12, 6))
ax.plot(train_df, label = 'train_data')
ax.plot(test_df, label = 'test_data')
ax.plot(predict_index, predicted_value, label = 'Prediction')
ax.fill_between(predict_index, predicted_upper, predicted_lower, color = 'k', alpha = 0.1, label = '0.95 Prediction Interval')
ax.legend(loc = 'lower left')
plt.show()

# %% [markdown]
# ## auto arima 모델

# %%
model = auto_arima(train_df, 
                            d = 1, 
                            start_p = 0, 
                            max_p = 3,
                            start_q = 0,
                            max_q = 3,
                            m = 1,
                            seasonal = False,
                           stepwise = True,
                           trace = True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1249.197, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1247.552, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1248.170, Time=0.33 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1247.968, Time=0.02 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=1247.589, Time=0.10 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1248.014, Time=0.11 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=1249.557, Time=0.16 sec
#  ARIMA(1,1,0)(0,0,0)[0]             : AIC=1246.528, Time=0.02 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : AIC=1246.367, Time=0.05 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : AIC=1248.359, Time=0.06 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=1248.353, Time=0.11 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=1246.921, Time=0.05 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : AIC=1250.351, Time=0.18 sec
#
# Best model:  ARIMA(2,1,0)(0,0,0)[0]
# ...

# %%
model.fit(train_df)
# Out:
# ARIMA(order=(2, 1, 0), scoring_args={}, suppress_warnings=True,
#       with_intercept=False)

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                  208
# Model:               SARIMAX(2, 1, 0)   Log Likelihood                -620.183
# Date:                Fri, 22 Jul 2022   AIC                           1246.367
# Time:                        23:36:50   BIC                           1256.365
# Sample:                             0   HQIC                          1250.410
#                                 - 208
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1164      0.080     -1.446      0.148      -0.274       0.041
# ar.L2          0.1028      0.079      1.295      0.195      -0.053       0.258
# sigma2        23.4304      1.356     17.274      0.000      20.772      26.089
# ...

# %% [markdown]
# ## VAR 모델
