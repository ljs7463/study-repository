# %%
import pandas as pd
df = pd.read_excel('data/SeriesReport-20230101054951_4fcbaa.xlsx')
# Out:
# C:\Users\jeongseokLim\anaconda3\envs\jupyter\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df
# Out:
#    Labor Force Statistics from the Current Population Survey  \
# 0                                 Original Data Value
# 1                                                 NaN
# 2                                          Series Id:
# 3                                 Seasonally Adjusted
# 4                                       Series title:
# 5                                 Labor force status:
# 6                                       Type of data:
# 7                                                Age:
# 8                                              Years:
# 9                                                 NaN
# 10                                               Year
# 11                                               2012
# 12                                               2013
# 13                                               2014
# 14                                               2015
# 15                                               2016
# ...
